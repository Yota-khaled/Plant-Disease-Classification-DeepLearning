# %% [markdown]
# # Import Libraries

# %%
# !pip install tensorflow --upgrade --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.6/620.6 MB 2.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 70.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 111.7 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 110.5 MB/s eta 0:00:0000:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# tf-keras 2.18.0 requires tensorflow<2.19,>=2.18, but you have tensorflow 2.20.0 which is incompatible.
# tensorflow-decision-forests 1.11.0 requires tensorflow==2.18.0, but you have tensorflow 2.20.0 which is incompatible.
# tensorflow-text 2.18.1 requires tensorflow<2.19,>=2.18.0, but you have tensorflow 2.20.0 which is incompatible.

# %%
import warnings, os, tensorflow as tf
import logging
import absl.logging
warnings.filterwarnings("ignore")
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
tf.get_logger().setLevel('ERROR')
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_DISABLE_MODEL_PRUNING'] = '1'
absl.logging.set_verbosity(absl.logging.ERROR)
logging.getLogger('tensorflow').setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

try:
    if not hasattr(tf.keras.backend, "_gradient_registry"):
        tf.keras.backend._gradient_registry = {}
    elif tf.keras.backend._gradient_registry is None:
        tf.keras.backend._gradient_registry = {}
except:
    pass

try:
    tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
except:
    pass

try:
    from tensorflow.python.util import deprecation
    deprecation._PRINT_DEPRECATION_WARNINGS = False
except:
    pass

# %%
import os
import numpy as np
import shutil
import hashlib
import random
from collections import defaultdict
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau ,Callback
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras.regularizers import l2
from sklearn.preprocessing import label_binarize
from tensorflow.keras.optimizers import Adam
import itertools
import seaborn as sns
import time

# %% [markdown]
# # Dataset Cleaning

# %%
ORIGINAL_DIR = "/kaggle/input/plantvillage dataset/color"
CLEAN_DIR = "/kaggle/working/plantvillage_clean"

if os.path.exists(CLEAN_DIR):
    shutil.rmtree(CLEAN_DIR)

print("Copying dataset and removing exact duplicates...\n")

hash_dict = {}           
duplicates_removed = 0
copied_images = 0

for root, dirs, files in os.walk(ORIGINAL_DIR):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            src_path = os.path.join(root, file)
            
            with open(src_path, "rb") as f:
                file_hash = hashlib.md5(f.read()).hexdigest()
            
            rel_path = os.path.relpath(src_path, ORIGINAL_DIR)
            dst_path = os.path.join(CLEAN_DIR, rel_path)
            dst_folder = os.path.dirname(dst_path)
            
            if file_hash not in hash_dict:
                os.makedirs(dst_folder, exist_ok=True)
                shutil.copy2(src_path, dst_path)
                hash_dict[file_hash] = dst_path
                copied_images += 1
            else:
                duplicates_removed += 1

print("Dataset cleaning completed!")
print(f"Unique images copied      : {copied_images:,}")
print(f"Exact duplicates skipped  : {duplicates_removed:,}")
print(f"Clean dataset path        : {CLEAN_DIR}")

SOURCE_DIR = CLEAN_DIR
# Out:
# Copying dataset and removing exact duplicates...
#
# Dataset cleaning completed!
# Unique images copied      : 54,284
# Exact duplicates skipped  : 21
# Clean dataset path        : /kaggle/working/plantvillage_clean

# %% [markdown]
# # Dataset Exploration & Visualization

# %%
SOURCE_DIR = "/kaggle/working/plantvillage_clean"

classes = sorted([d for d in os.listdir(SOURCE_DIR) 
                  if os.path.isdir(os.path.join(SOURCE_DIR, d))])[:6]

plt.figure(figsize=(15, 12))
plt.suptitle("Sample Images from First 6 Classes", 
             fontsize=18, fontweight='bold', y=0.98)

plot_num = 1
for cls in classes:
    cls_path = os.path.join(SOURCE_DIR, cls)
    images = [f for f in os.listdir(cls_path) 
              if f.lower().endswith(('.jpg', '.jpeg', '.png'))]
    samples = random.sample(images, min(3, len(images)))
    
    plant = cls.split("___")[0].replace("_", " ").title()
    disease = "Healthy" if len(cls.split("___")) == 1 else cls.split("___")[1].replace("_", " ").title()
    title = f"{plant} - {disease}"
    
    for img_file in samples:
        img_path = os.path.join(cls_path, img_file)
        img = plt.imread(img_path)
        
        plt.subplot(6, 3, plot_num)
        plt.imshow(img)
        if plot_num % 3 == 2: 
            plt.title(title, fontsize=13, fontweight='bold', pad=12)
        plt.axis('off')
        plot_num += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# # Config & Data Splitting

# %%
IMG_SIZE = 224
BATCH_SIZE = 16
NUM_EPOCHS = 30
FINE_TUNE_EPOCH=10
VALIDATION_SPLIT=0.15
TEST_SPLIT= 0.15

# %%
# Paths
SOURCE_DIR = "/kaggle/working/plantvillage_clean"   
WORK_DIR   = "/kaggle/working/plantvillage_split"

train_dir = os.path.join(WORK_DIR, "train")
val_dir   = os.path.join(WORK_DIR, "val")
test_dir  = os.path.join(WORK_DIR, "test")

# Clean previous split (fresh start)
for folder in [train_dir, val_dir, test_dir]:
    if os.path.exists(folder):
        shutil.rmtree(folder)

os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir,   exist_ok=True)
os.makedirs(test_dir,  exist_ok=True)

print("Splitting dataset... (70% train | 15% val | 15% test)")

classes = sorted([c for c in os.listdir(SOURCE_DIR) if os.path.isdir(os.path.join(SOURCE_DIR, c))])

for cls in classes:
    cls_path = os.path.join(SOURCE_DIR, cls)
    images = [os.path.join(cls_path, img) for img in os.listdir(cls_path)
              if img.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    # First: separate test set (15%)
    train_val_imgs, test_imgs = train_test_split(
        images, test_size=TEST_SPLIT, random_state=42, shuffle=True)
    
    # Then: from remaining 85%, take 15% of total remaining for validation
    train_imgs, val_imgs = train_test_split(
        train_val_imgs,
        test_size=VALIDATION_SPLIT / (1 - TEST_SPLIT),  
        random_state=42,
        shuffle=True
    )
    
    # Create class folders and copy images
    for split_dir, split_imgs in zip([train_dir, val_dir, test_dir],
                                     [train_imgs, val_imgs, test_imgs]):
        os.makedirs(os.path.join(split_dir, cls), exist_ok=True)
        for src_path in split_imgs:
            shutil.copy(src_path, os.path.join(split_dir, cls))

print("Dataset split completed successfully!")
print(f"Train → {train_dir}")
print(f"Val   → {val_dir}")
print(f"Test  → {test_dir}")
# Out:
# Splitting dataset... (70% train | 15% val | 15% test)
# Dataset split completed successfully!
# Train → /kaggle/working/plantvillage_split/train
# Val   → /kaggle/working/plantvillage_split/val
# Test  → /kaggle/working/plantvillage_split/test

# %%
# Check the new split folders 
print("Split completed successfully!")

print(f"\nTrain directory: {train_dir}")
print(f"Number of classes in train:", len(os.listdir(train_dir)))
print(f"Total train images: {sum(len(os.listdir(os.path.join(train_dir, c))) for c in os.listdir(train_dir))}")

print(f"\nValidation directory: {val_dir}")
print(f"Number of classes in val:  {len(os.listdir(val_dir))}")
print(f"Total val images:   {sum(len(os.listdir(os.path.join(val_dir, c))) for c in os.listdir(val_dir))}")

print(f"\nTest directory: {test_dir}")
print(f"Number of classes in test: {len(os.listdir(test_dir))}")
print(f"Total test images:  {sum(len(os.listdir(os.path.join(test_dir, c))) for c in os.listdir(test_dir))}")
# Out:
# Split completed successfully!
#
# Train directory: /kaggle/working/plantvillage_split/train
# Number of classes in train: 38
# Total train images: 37971
#
# Validation directory: /kaggle/working/plantvillage_split/val
# Number of classes in val:  38
# Total val images:   8154
#
# Test directory: /kaggle/working/plantvillage_split/test
# Number of classes in test: 38
# Total test images:  8159

# %% [markdown]
# # Data Generators

# %%
TRAIN_DIR = "/kaggle/working/plantvillage_split/train"
VAL_DIR   = "/kaggle/working/plantvillage_split/val"
TEST_DIR  = "/kaggle/working/plantvillage_split/test"

# %%
# Train datagen with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,    # NORMALIZED PIXEL VALUES TO [0,1]
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.1,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest',
)

# %%
# Validation & Test (no augmentation)
val_test_datagen = ImageDataGenerator(rescale=1./255)

# %%
#train data loader
train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True   

)
# Out:
# Found 37971 images belonging to 38 classes.

# %%
for images, labels in train_generator:
    print(images.shape, labels.shape)
    break
# Out:
# (16, 224, 224, 3) (16, 38)

# %%
#validation data loader
validation_generator = val_test_datagen.flow_from_directory(
    VAL_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 8154 images belonging to 38 classes.

# %%
test_generator = val_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 8159 images belonging to 38 classes.

# %%
class_names=list(train_generator.class_indices.keys())
class_names
# Out:
# ['Apple___Apple_scab',
#  'Apple___Black_rot',
#  'Apple___Cedar_apple_rust',
#  'Apple___healthy',
#  'Blueberry___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Cherry_(including_sour)___healthy',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Corn_(maize)___Common_rust_',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Corn_(maize)___healthy',
#  'Grape___Black_rot',
#  'Grape___Esca_(Black_Measles)',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Grape___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Peach___Bacterial_spot',
#  'Peach___healthy',
#  'Pepper,_bell___Bacterial_spot',
#  'Pepper,_bell___healthy',
#  'Potato___Early_blight',
#  'Potato___Late_blight',
#  'Potato___healthy',
#  'Raspberry___healthy',
#  'Soybean___healthy',
#  'Squash___Powdery_mildew',
#  'Strawberry___Leaf_scorch',
#  'Strawberry___healthy',
#  'Tomato___Bacterial_spot',
#  'Tomato___Early_blight',
#  'Tomato___Late_blight',
#  'Tomato___Leaf_Mold',
#  'Tomato___Septoria_leaf_spot',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Tomato___Target_Spot',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Tomato_mosaic_virus',
#  'Tomato___healthy']

# %% [markdown]
# ## VGG-19 Architecture Explanation
# **VGG-19 is a CNN with 19 layers (16 conv + 3 dense). Steps: Input (224x224x3) → Conv blocks (with 3x3 filters) → MaxPooling → FC layers.**
#
# **Graph:** ![image.png](attachment:a25811b2-89a2-4c0c-89ad-4fa02410f581.png)
#
# **Reference:** Simonyan & Zisserman (2014) - https://arxiv.org/abs/1409.1556

# %% [markdown]
# # Build VGG-19 From Scratch

# %%
model = Sequential()

# Block 1
model.add(Conv2D(64, (3,3), activation='relu', padding='same', input_shape=(224,224,3)))
model.add(Conv2D(64, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

# Block 2
model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(Conv2D(128, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

# Block 3
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(Conv2D(256, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

# Block 4
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

# Block 5
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(Conv2D(512, (3,3), activation='relu', padding='same'))
model.add(MaxPooling2D((2,2), strides=(2,2)))

# Fully connected layers
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(train_generator.num_classes, activation='softmax'))

model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764297886.092740      47 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4096)           │   102,764,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4096)           │    16,781,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 38)             │       155,686 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 139,725,926 (533.01 MB)
#  Trainable params: 139,725,926 (533.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Compile & Train VGG19

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0001),   
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

checkpoint = ModelCheckpoint(
    "/kaggle/working/vgg19_best.keras",
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=4,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=1e-7,
    verbose=1
)


callbacks = [checkpoint, early_stop, reduce_lr]

history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=NUM_EPOCHS,  
    verbose=1, 
    callbacks=callbacks
)
# Out:
# Epoch 1/30
#    1/2375 ━━━━━━━━━━━━━━━━━━━━ 13:19:20 20s/step - accuracy: 0.0000e+00 - loss: 3.6375
# I0000 00:00:1764297907.779712     150 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.1754 - loss: 3.0935
# Epoch 1: val_accuracy improved from None to 0.33795, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 504s 204ms/step - accuracy: 0.2302 - loss: 2.8537 - val_accuracy: 0.3380 - val_loss: 2.3879 - learning_rate: 1.0000e-04
# Epoch 2/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.3932 - loss: 2.0963
# Epoch 2: val_accuracy improved from 0.33795 to 0.63717, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 475s 200ms/step - accuracy: 0.4655 - loss: 1.8191 - val_accuracy: 0.6372 - val_loss: 1.1596 - learning_rate: 1.0000e-04
# Epoch 3/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.6322 - loss: 1.1847
# Epoch 3: val_accuracy improved from 0.63717 to 0.77078, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 467s 196ms/step - accuracy: 0.6682 - loss: 1.0635 - val_accuracy: 0.7708 - val_loss: 0.7131 - learning_rate: 1.0000e-04
# Epoch 4/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7494 - loss: 0.7838
# Epoch 4: val_accuracy improved from 0.77078 to 0.84383, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 472s 198ms/step - accuracy: 0.7642 - loss: 0.7400 - val_accuracy: 0.8438 - val_loss: 0.4665 - learning_rate: 1.0000e-04
# Epoch 5/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8080 - loss: 0.6026
# Epoch 5: val_accuracy improved from 0.84383 to 0.86394, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 469s 198ms/step - accuracy: 0.8160 - loss: 0.5688 - val_accuracy: 0.8639 - val_loss: 0.4080 - learning_rate: 1.0000e-04
# Epoch 6/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8427 - loss: 0.4831
# Epoch 6: val_accuracy improved from 0.86394 to 0.88551, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 468s 197ms/step - accuracy: 0.8514 - loss: 0.4614 - val_accuracy: 0.8855 - val_loss: 0.3479 - learning_rate: 1.0000e-04
# Epoch 7/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8697 - loss: 0.3980
# Epoch 7: val_accuracy improved from 0.88551 to 0.89409, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 467s 197ms/step - accuracy: 0.8731 - loss: 0.3862 - val_accuracy: 0.8941 - val_loss: 0.3169 - learning_rate: 1.0000e-04
# Epoch 8/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8892 - loss: 0.3369
# Epoch 8: val_accuracy improved from 0.89409 to 0.89838, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 470s 198ms/step - accuracy: 0.8907 - loss: 0.3345 - val_accuracy: 0.8984 - val_loss: 0.3099 - learning_rate: 1.0000e-04
# Epoch 9/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8989 - loss: 0.3072
# Epoch 9: val_accuracy improved from 0.89838 to 0.93687, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 465s 196ms/step - accuracy: 0.9006 - loss: 0.2981 - val_accuracy: 0.9369 - val_loss: 0.1910 - learning_rate: 1.0000e-04
# Epoch 10/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9127 - loss: 0.2654
# Epoch 10: val_accuracy improved from 0.93687 to 0.94300, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 470s 198ms/step - accuracy: 0.9133 - loss: 0.2625 - val_accuracy: 0.9430 - val_loss: 0.1841 - learning_rate: 1.0000e-04
# Epoch 11/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9193 - loss: 0.2457
# Epoch 11: val_accuracy did not improve from 0.94300
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 463s 195ms/step - accuracy: 0.9208 - loss: 0.2396 - val_accuracy: 0.9251 - val_loss: 0.2296 - learning_rate: 1.0000e-04
# Epoch 12/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9274 - loss: 0.2215
# Epoch 12: val_accuracy did not improve from 0.94300
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 459s 193ms/step - accuracy: 0.9297 - loss: 0.2165 - val_accuracy: 0.9250 - val_loss: 0.2472 - learning_rate: 1.0000e-04
# Epoch 13/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9347 - loss: 0.2017
# Epoch 13: val_accuracy improved from 0.94300 to 0.94717, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 473s 199ms/step - accuracy: 0.9359 - loss: 0.1997 - val_accuracy: 0.9472 - val_loss: 0.1690 - learning_rate: 1.0000e-04
# Epoch 14/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9358 - loss: 0.1916
# Epoch 14: val_accuracy did not improve from 0.94717
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 463s 195ms/step - accuracy: 0.9365 - loss: 0.1921 - val_accuracy: 0.9440 - val_loss: 0.1691 - learning_rate: 1.0000e-04
# Epoch 15/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9450 - loss: 0.1703
# Epoch 15: val_accuracy did not improve from 0.94717
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 465s 196ms/step - accuracy: 0.9435 - loss: 0.1759 - val_accuracy: 0.9439 - val_loss: 0.1728 - learning_rate: 1.0000e-04
# Epoch 16/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9500 - loss: 0.1515
# Epoch 16: val_accuracy improved from 0.94717 to 0.95440, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 472s 199ms/step - accuracy: 0.9490 - loss: 0.1565 - val_accuracy: 0.9544 - val_loss: 0.1367 - learning_rate: 1.0000e-04
# Epoch 17/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9495 - loss: 0.1528
# Epoch 17: val_accuracy improved from 0.95440 to 0.96274, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 466s 196ms/step - accuracy: 0.9491 - loss: 0.1536 - val_accuracy: 0.9627 - val_loss: 0.1175 - learning_rate: 1.0000e-04
# Epoch 18/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9547 - loss: 0.1365
# Epoch 18: val_accuracy did not improve from 0.96274
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 464s 195ms/step - accuracy: 0.9540 - loss: 0.1399 - val_accuracy: 0.9605 - val_loss: 0.1110 - learning_rate: 1.0000e-04
# Epoch 19/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9549 - loss: 0.1342
# Epoch 19: val_accuracy improved from 0.96274 to 0.96286, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 470s 198ms/step - accuracy: 0.9556 - loss: 0.1331 - val_accuracy: 0.9629 - val_loss: 0.1230 - learning_rate: 1.0000e-04
# Epoch 20/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9581 - loss: 0.1284
# Epoch 20: val_accuracy did not improve from 0.96286
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 464s 195ms/step - accuracy: 0.9573 - loss: 0.1293 - val_accuracy: 0.9592 - val_loss: 0.1276 - learning_rate: 1.0000e-04
# Epoch 21/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9599 - loss: 0.1202
# Epoch 21: val_accuracy did not improve from 0.96286
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 462s 195ms/step - accuracy: 0.9597 - loss: 0.1204 - val_accuracy: 0.9546 - val_loss: 0.1387 - learning_rate: 1.0000e-04
# Epoch 22/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9808 - loss: 0.0571
# Epoch 22: val_accuracy improved from 0.96286 to 0.98026, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 468s 197ms/step - accuracy: 0.9835 - loss: 0.0492 - val_accuracy: 0.9803 - val_loss: 0.0639 - learning_rate: 2.0000e-05
# Epoch 23/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9858 - loss: 0.0405
# Epoch 23: val_accuracy improved from 0.98026 to 0.98382, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 475s 200ms/step - accuracy: 0.9863 - loss: 0.0395 - val_accuracy: 0.9838 - val_loss: 0.0556 - learning_rate: 2.0000e-05
# Epoch 24/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9863 - loss: 0.0390
# Epoch 24: val_accuracy did not improve from 0.98382
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 475s 200ms/step - accuracy: 0.9869 - loss: 0.0372 - val_accuracy: 0.9830 - val_loss: 0.0522 - learning_rate: 2.0000e-05
# Epoch 25/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9870 - loss: 0.0358
# Epoch 25: val_accuracy improved from 0.98382 to 0.98468, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 473s 199ms/step - accuracy: 0.9877 - loss: 0.0358 - val_accuracy: 0.9847 - val_loss: 0.0532 - learning_rate: 2.0000e-05
# Epoch 26/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9904 - loss: 0.0288
# Epoch 26: val_accuracy did not improve from 0.98468
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 463s 195ms/step - accuracy: 0.9898 - loss: 0.0301 - val_accuracy: 0.9814 - val_loss: 0.0635 - learning_rate: 2.0000e-05
# Epoch 27/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9903 - loss: 0.0290
# Epoch 27: val_accuracy improved from 0.98468 to 0.98737, saving model to /kaggle/working/vgg19_best.keras
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 476s 200ms/step - accuracy: 0.9899 - loss: 0.0314 - val_accuracy: 0.9874 - val_loss: 0.0446 - learning_rate: 2.0000e-05
# Epoch 28/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9902 - loss: 0.0314
# Epoch 28: val_accuracy did not improve from 0.98737
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 473s 199ms/step - accuracy: 0.9908 - loss: 0.0288 - val_accuracy: 0.9821 - val_loss: 0.0611 - learning_rate: 2.0000e-05
# Epoch 29/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9907 - loss: 0.0292
# Epoch 29: val_accuracy did not improve from 0.98737
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 473s 199ms/step - accuracy: 0.9902 - loss: 0.0299 - val_accuracy: 0.9841 - val_loss: 0.0581 - learning_rate: 2.0000e-05
# Epoch 30/30
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.9905 - loss: 0.0295
# Epoch 30: val_accuracy did not improve from 0.98737
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 2375/2375 ━━━━━━━━━━━━━━━━━━━━ 472s 199ms/step - accuracy: 0.9909 - loss: 0.0274 - val_accuracy: 0.9783 - val_loss: 0.0852 - learning_rate: 2.0000e-05

# %%
best_val_acc = max(history.history['val_accuracy'])
best_epoch = history.history['val_accuracy'].index(best_val_acc) + 1
final_val_acc = history.history['val_accuracy'][-1]
final_train_acc = history.history['accuracy'][-1]

print(f"Best validation accuracy: {best_val_acc:.4f} at epoch {best_epoch}")
print(f"Final validation accuracy: {final_val_acc:.4f}")
print(f"Final training accuracy: {final_train_acc:.4f}")
print(f"Best model saved as: /kaggle/working/vgg19_best.keras")
# Out:
# Best validation accuracy: 0.9874 at epoch 27
# Final validation accuracy: 0.9783
# Final training accuracy: 0.9909
# Best model saved as: /kaggle/working/vgg19_best.h5

# %%
test_generator.reset()   

test_loss, test_accuracy = model.evaluate(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE + 1,
    verbose=1
)

print(f"\nFinal Test Accuracy  = {test_accuracy*100:.3f}%")
print(f"Final Test Loss       = {test_loss:.4f}")
# Out:
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 29s 56ms/step - accuracy: 0.9762 - loss: 0.0812
#
# Final Test Accuracy  = 97.623%
# Final Test Loss       = 0.0812

# %%
y_pred = model.predict(test_generator, 
                       steps = test_generator.samples // test_generator.batch_size + 1,
                       verbose=1)
y_pred_classes = np.argmax(y_pred, axis=1)

y_true = test_generator.classes
# Out:
# 511/511 ━━━━━━━━━━━━━━━━━━━━ 28s 54ms/step

# %% [markdown]
# # Loss & Accuracy

# %%
plt.figure(figsize=(14,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Evaluation Matrix

# %%
plt.figure(figsize=(12,10))
cm = confusion_matrix(y_true, y_pred_classes)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - True Unseen Test Set')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# # Classification Report (Precision, Recall, F1-score)

# %%
# 5. Classification Report
print("Classification Report on True Test Set:\n")
class_names = list(test_generator.class_indices.keys())
print(classification_report(y_true, y_pred_classes, target_names=class_names))
# Out:
# Classification Report on True Test Set:
#
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.98      0.98      0.98        95
#                                  Apple___Black_rot       0.96      1.00      0.98        94
#                           Apple___Cedar_apple_rust       0.98      1.00      0.99        42
#                                    Apple___healthy       0.98      0.97      0.97       247
#                                Blueberry___healthy       1.00      0.99      0.99       226
#           Cherry_(including_sour)___Powdery_mildew       0.99      0.98      0.99       158
#                  Cherry_(including_sour)___healthy       0.98      0.98      0.98       129
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.89      0.96      0.92        77
#                        Corn_(maize)___Common_rust_       1.00      1.00      1.00       179
#                Corn_(maize)___Northern_Leaf_Blight       0.98      0.92      0.95       148
#                             Corn_(maize)___healthy       1.00      1.00      1.00       175
#                                  Grape___Black_rot       0.98      0.99      0.99       177
#                       Grape___Esca_(Black_Measles)       1.00      1.00      1.00       208
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.99      0.99      0.99       162
#                                    Grape___healthy       1.00      1.00      1.00        64
#           Orange___Haunglongbing_(Citrus_greening)       1.00      0.98      0.99       827
#                             Peach___Bacterial_spot       1.00      0.97      0.99       345
#                                    Peach___healthy       0.96      1.00      0.98        54
#                      Pepper,_bell___Bacterial_spot       0.99      0.97      0.98       150
#                             Pepper,_bell___healthy       0.94      0.99      0.96       222
#                              Potato___Early_blight       0.97      1.00      0.98       150
#                               Potato___Late_blight       0.98      0.97      0.98       150
#                                   Potato___healthy       0.94      0.65      0.77        23
#                                Raspberry___healthy       1.00      0.96      0.98        56
#                                  Soybean___healthy       0.98      0.99      0.99       764
#                            Squash___Powdery_mildew       1.00      0.99      1.00       276
#                           Strawberry___Leaf_scorch       0.99      1.00      1.00       167
#                               Strawberry___healthy       0.99      1.00      0.99        69
#                            Tomato___Bacterial_spot       0.99      0.93      0.96       320
#                              Tomato___Early_blight       0.93      0.95      0.94       150
#                               Tomato___Late_blight       0.94      0.98      0.96       287
#                                 Tomato___Leaf_Mold       0.99      0.96      0.97       143
#                        Tomato___Septoria_leaf_spot       0.94      0.98      0.96       266
#      Tomato___Spider_mites Two-spotted_spider_mite       0.93      0.91      0.92       252
#                               Tomato___Target_Spot       0.94      0.88      0.91       211
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       1.00      0.99      1.00       804
#                       Tomato___Tomato_mosaic_virus       1.00      0.98      0.99        56
#                                   Tomato___healthy       0.90      1.00      0.94       239
#
#                                           accuracy                           0.98      8162
#                                          macro avg       0.97      0.97      0.97      8162
#                                       weighted avg       0.98      0.98      0.98      8162

# %% [markdown]
# # ROC & AUC

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import numpy as np

plt.figure(figsize=(12, 10))

y_true_bin = label_binarize(y_true, classes=np.arange(test_generator.num_classes))

if y_true_bin.ndim == 1:
    y_true_bin = y_true_bin.reshape(-1, 1)

for i in range(test_generator.num_classes):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_names[i]} (AUC = {roc_auc:.3f})') 

plt.plot([0, 1], [0, 1], 'k--', label='Random (AUC = 0.50)')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=12)
plt.ylabel('True Positive Rate', fontsize=12)
plt.title('ROC Curves - All 38 Plant Disease Classes', fontsize=16, pad=20)
plt.legend(loc="lower right", fontsize=8, ncol=2)     
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **MobileNet/VIT models**

# %% [markdown]
# # **1. MobileNet model**

# %%
# Model Build

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

base = MobileNetV2(
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False,
    weights='imagenet'
)
base.trainable = False

x = base.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
out = Dense(len(class_names), activation='softmax')(x)

model_mn = Model(inputs=base.input, outputs=out)
model_mn.compile(optimizer=Adam(1e-3),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])

# %%
# Callbacks

best_path = "/kaggle/working/mobilenet_best.h5"

callbacks = [
    ModelCheckpoint(filepath=best_path,
                    monitor="val_accuracy",
                    save_best_only=True,
                    mode="max",
                    verbose=1),

    EarlyStopping(monitor="val_accuracy",
                  patience=5,
                  restore_best_weights=True,
                  mode="max",
                  verbose=1),

    ReduceLROnPlateau(monitor="val_loss",
                      factor=0.3,
                      patience=3,
                      verbose=1)
]

# %%
# Training

history_frozen = model_mn.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=20,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7258 - loss: 1.0184
# Epoch 1: val_accuracy improved from None to 0.90974, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 397s 164ms/step - accuracy: 0.8196 - loss: 0.6191 - val_accuracy: 0.9097 - val_loss: 0.2779 - learning_rate: 0.0010
# Epoch 2/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8867 - loss: 0.3545
# Epoch 2: val_accuracy improved from 0.90974 to 0.91710, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 379s 160ms/step - accuracy: 0.8895 - loss: 0.3433 - val_accuracy: 0.9171 - val_loss: 0.2479 - learning_rate: 0.0010
# Epoch 3/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8997 - loss: 0.3071
# Epoch 3: val_accuracy improved from 0.91710 to 0.93095, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 378s 159ms/step - accuracy: 0.8984 - loss: 0.3107 - val_accuracy: 0.9310 - val_loss: 0.2122 - learning_rate: 0.0010
# Epoch 4/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9049 - loss: 0.2957
# Epoch 4: val_accuracy did not improve from 0.93095
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 381s 161ms/step - accuracy: 0.9048 - loss: 0.2944 - val_accuracy: 0.9203 - val_loss: 0.2418 - learning_rate: 0.0010
# Epoch 5/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9070 - loss: 0.2862
# Epoch 5: val_accuracy improved from 0.93095 to 0.93206, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 381s 161ms/step - accuracy: 0.9075 - loss: 0.2860 - val_accuracy: 0.9321 - val_loss: 0.2142 - learning_rate: 0.0010
# Epoch 6/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9107 - loss: 0.2786
# Epoch 6: val_accuracy did not improve from 0.93206
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 379s 160ms/step - accuracy: 0.9089 - loss: 0.2867 - val_accuracy: 0.9313 - val_loss: 0.2141 - learning_rate: 0.0010
# Epoch 7/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9194 - loss: 0.2522
# Epoch 7: val_accuracy improved from 0.93206 to 0.94101, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 378s 159ms/step - accuracy: 0.9218 - loss: 0.2429 - val_accuracy: 0.9410 - val_loss: 0.1777 - learning_rate: 3.0000e-04
# Epoch 8/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9229 - loss: 0.2323
# Epoch 8: val_accuracy did not improve from 0.94101
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 377s 159ms/step - accuracy: 0.9233 - loss: 0.2339 - val_accuracy: 0.9404 - val_loss: 0.1803 - learning_rate: 3.0000e-04
# Epoch 9/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9253 - loss: 0.2240
# Epoch 9: val_accuracy did not improve from 0.94101
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 375s 158ms/step - accuracy: 0.9243 - loss: 0.2283 - val_accuracy: 0.9400 - val_loss: 0.1799 - learning_rate: 3.0000e-04
# Epoch 10/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9288 - loss: 0.2187
# Epoch 10: val_accuracy improved from 0.94101 to 0.94432, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 376s 158ms/step - accuracy: 0.9283 - loss: 0.2204 - val_accuracy: 0.9443 - val_loss: 0.1685 - learning_rate: 3.0000e-04
# Epoch 11/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9250 - loss: 0.2266
# Epoch 11: val_accuracy improved from 0.94432 to 0.94518, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 378s 159ms/step - accuracy: 0.9258 - loss: 0.2241 - val_accuracy: 0.9452 - val_loss: 0.1627 - learning_rate: 3.0000e-04
# Epoch 12/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9277 - loss: 0.2087
# Epoch 12: val_accuracy improved from 0.94518 to 0.94690, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 378s 159ms/step - accuracy: 0.9282 - loss: 0.2126 - val_accuracy: 0.9469 - val_loss: 0.1607 - learning_rate: 3.0000e-04
# Epoch 13/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9265 - loss: 0.2216
# Epoch 13: val_accuracy did not improve from 0.94690
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 380s 160ms/step - accuracy: 0.9288 - loss: 0.2173 - val_accuracy: 0.9431 - val_loss: 0.1704 - learning_rate: 3.0000e-04
# Epoch 14/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9282 - loss: 0.2180
# Epoch 14: val_accuracy did not improve from 0.94690
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 378s 159ms/step - accuracy: 0.9274 - loss: 0.2156 - val_accuracy: 0.9454 - val_loss: 0.1673 - learning_rate: 3.0000e-04
# Epoch 15/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9274 - loss: 0.2088
# Epoch 15: val_accuracy improved from 0.94690 to 0.94714, saving model to /kaggle/working/mobilenet_best.h5
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 375s 158ms/step - accuracy: 0.9298 - loss: 0.2066 - val_accuracy: 0.9471 - val_loss: 0.1609 - learning_rate: 3.0000e-04
# Epoch 16/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9325 - loss: 0.1951
# Epoch 16: val_accuracy improved from 0.94714 to 0.94935, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 376s 159ms/step - accuracy: 0.9326 - loss: 0.2005 - val_accuracy: 0.9493 - val_loss: 0.1556 - learning_rate: 9.0000e-05
# Epoch 17/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9347 - loss: 0.1964
# Epoch 17: val_accuracy did not improve from 0.94935
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 379s 160ms/step - accuracy: 0.9340 - loss: 0.1978 - val_accuracy: 0.9475 - val_loss: 0.1571 - learning_rate: 9.0000e-05
# Epoch 18/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9358 - loss: 0.1919
# Epoch 18: val_accuracy did not improve from 0.94935
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 376s 158ms/step - accuracy: 0.9349 - loss: 0.1949 - val_accuracy: 0.9490 - val_loss: 0.1560 - learning_rate: 9.0000e-05
# Epoch 19/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.9359 - loss: 0.1954
# Epoch 19: val_accuracy did not improve from 0.94935
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 375s 158ms/step - accuracy: 0.9337 - loss: 0.1987 - val_accuracy: 0.9482 - val_loss: 0.1548 - learning_rate: 9.0000e-05
# Epoch 20/20
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9336 - loss: 0.1956
# Epoch 20: val_accuracy improved from 0.94935 to 0.95107, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 378s 159ms/step - accuracy: 0.9335 - loss: 0.1983 - val_accuracy: 0.9511 - val_loss: 0.1503 - learning_rate: 9.0000e-05
# Restoring model weights from the end of the best epoch: 20.

# %%
# Unfreeze + Fine-Tuning

for layer in base.layers[-40:]:
    layer.trainable = True

model_mn.compile(optimizer=Adam(1e-5),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])

history_ft = model_mn.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=15,
    callbacks=callbacks
)
# Out:
# Epoch 1/15
# 2025-12-03 20:13:17.521335: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-03 20:13:17.717500: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.7462 - loss: 1.3345
# Epoch 1: val_accuracy did not improve from 0.95107
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 406s 164ms/step - accuracy: 0.8285 - loss: 0.6850 - val_accuracy: 0.9371 - val_loss: 0.1883 - learning_rate: 1.0000e-05
# Epoch 2/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8977 - loss: 0.3200
# Epoch 2: val_accuracy did not improve from 0.95107
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 379s 160ms/step - accuracy: 0.9080 - loss: 0.2861 - val_accuracy: 0.9508 - val_loss: 0.1454 - learning_rate: 1.0000e-05
# Epoch 3/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9189 - loss: 0.2456
# Epoch 3: val_accuracy improved from 0.95107 to 0.95879, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 380s 160ms/step - accuracy: 0.9228 - loss: 0.2302 - val_accuracy: 0.9588 - val_loss: 0.1213 - learning_rate: 1.0000e-05
# Epoch 4/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9372 - loss: 0.1887
# Epoch 4: val_accuracy improved from 0.95879 to 0.96701, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 379s 160ms/step - accuracy: 0.9390 - loss: 0.1804 - val_accuracy: 0.9670 - val_loss: 0.1018 - learning_rate: 1.0000e-05
# Epoch 5/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9455 - loss: 0.1652
# Epoch 5: val_accuracy improved from 0.96701 to 0.96750, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 378s 159ms/step - accuracy: 0.9464 - loss: 0.1582 - val_accuracy: 0.9675 - val_loss: 0.0934 - learning_rate: 1.0000e-05
# Epoch 6/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9543 - loss: 0.1357
# Epoch 6: val_accuracy improved from 0.96750 to 0.96934, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 381s 160ms/step - accuracy: 0.9533 - loss: 0.1379 - val_accuracy: 0.9693 - val_loss: 0.0885 - learning_rate: 1.0000e-05
# Epoch 7/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9591 - loss: 0.1230
# Epoch 7: val_accuracy improved from 0.96934 to 0.97192, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 380s 160ms/step - accuracy: 0.9598 - loss: 0.1198 - val_accuracy: 0.9719 - val_loss: 0.0838 - learning_rate: 1.0000e-05
# Epoch 8/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9637 - loss: 0.1086
# Epoch 8: val_accuracy improved from 0.97192 to 0.97633, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 378s 159ms/step - accuracy: 0.9631 - loss: 0.1092 - val_accuracy: 0.9763 - val_loss: 0.0718 - learning_rate: 1.0000e-05
# Epoch 9/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9639 - loss: 0.1063
# Epoch 9: val_accuracy did not improve from 0.97633
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 378s 159ms/step - accuracy: 0.9654 - loss: 0.1014 - val_accuracy: 0.9750 - val_loss: 0.0729 - learning_rate: 1.0000e-05
# Epoch 10/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9677 - loss: 0.0942
# Epoch 10: val_accuracy did not improve from 0.97633
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 381s 160ms/step - accuracy: 0.9687 - loss: 0.0898 - val_accuracy: 0.9740 - val_loss: 0.0760 - learning_rate: 1.0000e-05
# Epoch 11/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.9720 - loss: 0.0813
# Epoch 11: val_accuracy did not improve from 0.97633
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 383s 161ms/step - accuracy: 0.9705 - loss: 0.0839 - val_accuracy: 0.9749 - val_loss: 0.0706 - learning_rate: 1.0000e-05
# Epoch 12/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9727 - loss: 0.0821
# Epoch 12: val_accuracy improved from 0.97633 to 0.97903, saving model to /kaggle/working/mobilenet_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 377s 159ms/step - accuracy: 0.9735 - loss: 0.0781 - val_accuracy: 0.9790 - val_loss: 0.0649 - learning_rate: 1.0000e-05
# Epoch 13/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9751 - loss: 0.0691
# Epoch 13: val_accuracy did not improve from 0.97903
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 376s 158ms/step - accuracy: 0.9753 - loss: 0.0700 - val_accuracy: 0.9758 - val_loss: 0.0689 - learning_rate: 1.0000e-05
# Epoch 14/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.9770 - loss: 0.0667
# Epoch 14: val_accuracy did not improve from 0.97903
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 379s 160ms/step - accuracy: 0.9776 - loss: 0.0663 - val_accuracy: 0.9771 - val_loss: 0.0668 - learning_rate: 1.0000e-05
# Epoch 15/15
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9770 - loss: 0.0655
# Epoch 15: val_accuracy did not improve from 0.97903
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 377s 159ms/step - accuracy: 0.9772 - loss: 0.0647 - val_accuracy: 0.9735 - val_loss: 0.0800 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 12.

# %%
# Reset generator
test_generator.reset()

# Predictions
y_pred = model_mn.predict(test_generator, steps=test_generator.samples // BATCH_SIZE + 1, verbose=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# True labels
y_true = test_generator.classes
# Out:
# 510/510 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step

# %%
from sklearn.metrics import classification_report

class_names = list(train_generator.class_indices.keys())

report = classification_report(y_true, y_pred_classes, target_names=class_names)
print("Classification Report:\n")
print(report)
# Out:
# Classification Report:
#
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.98      0.94      0.96        95
#                                  Apple___Black_rot       1.00      1.00      1.00        94
#                           Apple___Cedar_apple_rust       0.98      0.98      0.98        42
#                                    Apple___healthy       0.99      1.00      0.99       246
#                                Blueberry___healthy       0.99      1.00      1.00       226
#           Cherry_(including_sour)___Powdery_mildew       1.00      0.99      0.99       158
#                  Cherry_(including_sour)___healthy       0.99      0.99      0.99       129
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.76      0.92      0.84        77
#                        Corn_(maize)___Common_rust_       0.98      1.00      0.99       179
#                Corn_(maize)___Northern_Leaf_Blight       0.96      0.82      0.89       148
#                             Corn_(maize)___healthy       0.99      1.00      1.00       175
#                                  Grape___Black_rot       0.98      1.00      0.99       177
#                       Grape___Esca_(Black_Measles)       1.00      0.99      1.00       208
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       1.00      1.00      1.00       162
#                                    Grape___healthy       1.00      1.00      1.00        64
#           Orange___Haunglongbing_(Citrus_greening)       1.00      1.00      1.00       827
#                             Peach___Bacterial_spot       0.99      1.00      0.99       345
#                                    Peach___healthy       0.98      1.00      0.99        54
#                      Pepper,_bell___Bacterial_spot       0.96      0.99      0.97       150
#                             Pepper,_bell___healthy       0.98      1.00      0.99       222
#                              Potato___Early_blight       0.99      0.99      0.99       150
#                               Potato___Late_blight       0.98      0.97      0.97       150
#                                   Potato___healthy       0.95      0.83      0.88        23
#                                Raspberry___healthy       1.00      1.00      1.00        56
#                                  Soybean___healthy       0.99      1.00      1.00       764
#                            Squash___Powdery_mildew       1.00      1.00      1.00       276
#                           Strawberry___Leaf_scorch       1.00      0.99      1.00       167
#                               Strawberry___healthy       1.00      0.99      0.99        69
#                            Tomato___Bacterial_spot       0.97      0.97      0.97       320
#                              Tomato___Early_blight       0.94      0.79      0.86       150
#                               Tomato___Late_blight       0.95      0.97      0.96       286
#                                 Tomato___Leaf_Mold       0.97      0.97      0.97       143
#                        Tomato___Septoria_leaf_spot       0.94      0.95      0.95       266
#      Tomato___Spider_mites Two-spotted_spider_mite       0.96      0.87      0.91       252
#                               Tomato___Target_Spot       0.87      0.88      0.87       211
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       1.00      0.99      1.00       804
#                       Tomato___Tomato_mosaic_virus       0.96      0.96      0.96        56
#                                   Tomato___healthy       0.85      1.00      0.92       238
#
#                                           accuracy                           0.98      8159
#                                          macro avg       0.97      0.97      0.97      8159
#                                       weighted avg       0.98      0.98      0.98      8159

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - MobileNetV2')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
plt.figure(figsize=(14,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history_frozen.history['accuracy'] + history_ft.history['accuracy'], label='Train Accuracy')
plt.plot(history_frozen.history['val_accuracy'] + history_ft.history['val_accuracy'], label='Validation Accuracy')
plt.title('MobileNetV2 Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(history_frozen.history['loss'] + history_ft.history['loss'], label='Train Loss')
plt.plot(history_frozen.history['val_loss'] + history_ft.history['val_loss'], label='Validation Loss')
plt.title('MobileNetV2 Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import numpy as np

y_true_bin = label_binarize(y_true, classes=np.arange(len(class_names)))
if y_true_bin.ndim == 1:
    y_true_bin = y_true_bin.reshape(-1, 1)

plt.figure(figsize=(12,10))
for i in range(len(class_names)):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_names[i]} (AUC = {roc_auc:.3f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random (AUC = 0.5)')
plt.title('ROC Curves - MobileNetV2')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right", fontsize=8, ncol=2)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
best_frozen_path = "/kaggle/working/mobilenetv2_best_frozen.h5"


model_mn.save(best_frozen_path)
print(f"Best frozen model saved at: {best_frozen_path}")


final_ft_path = "/kaggle/working/mobilenetv2_final_ft.h5"
model_mn.save(final_ft_path)
print(f"Final fine-tuned model saved at: {final_ft_path}")
# Out:
# Best frozen model saved at: /kaggle/working/mobilenetv2_best_frozen.h5
# Final fine-tuned model saved at: /kaggle/working/mobilenetv2_final_ft.h5

# %% [markdown]
# # **2. VIT model**

# %%
# !pip install vit-keras
# Out:
# Requirement already satisfied: vit-keras in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from vit-keras) (1.15.3)
# Requirement already satisfied: validators in /usr/local/lib/python3.11/dist-packages (from vit-keras) (0.35.0)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy->vit-keras) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy->vit-keras) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy->vit-keras) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy->vit-keras) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy->vit-keras) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy->vit-keras) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.5,>=1.23.5->scipy->vit-keras) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.5,>=1.23.5->scipy->vit-keras) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.5,>=1.23.5->scipy->vit-keras) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.5,>=1.23.5->scipy->vit-keras) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.5,>=1.23.5->scipy->vit-keras) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.5,>=1.23.5->scipy->vit-keras) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.5,>=1.23.5->scipy->vit-keras) (2024.2.0)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from vit_keras import vit

# Download and load the pre-trained ViT model
base = vit.vit_b16(
    image_size=IMG_SIZE,
    activation='softmax',
    pretrained=True,
    include_top=False,
    pretrained_top=False
)

base.trainable = False

x = base.output
x = Dropout(0.3)(x)
out = Dense(len(class_names), activation='softmax')(x)

model_vit = Model(inputs=base.input, outputs=out)

model_vit.compile(optimizer=Adam(learning_rate=1e-4), 
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

model_vit.summary()
# Out:
# Model: "functional_44"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_34 (InputLayer)     │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Conv2D)              │ (None, 14, 14, 768)    │       590,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_2 (Reshape)             │ (None, 196, 768)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ class_token (ClassToken)        │ (None, 197, 768)       │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_posembed_input      │ (None, 197, 768)       │       151,296 │
# │ (AddPositionEmbs)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_0      │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_1      │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_2      │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_3      │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_4      │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_5      │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_6      │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_7      │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_8      │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_9      │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_10     │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoderblock_11     │ [(None, 197, 768),     │     7,087,872 │
# │ (TransformerBlock)              │ (None, 12, None,       │               │
# │                                 │ None)]                 │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Transformer_encoder_norm        │ (None, 197, 768)       │         1,536 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ ExtractToken (Lambda)           │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_116 (Dropout)           │ (None, 768)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 38)             │        29,222 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 85,827,878 (327.41 MB)
#  Trainable params: 29,222 (114.15 KB)
#  Non-trainable params: 85,798,656 (327.30 MB)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

best_path = "/kaggle/working/vit_best.h5"

callbacks = [
    ModelCheckpoint(filepath=best_path,
                    monitor="val_accuracy",
                    save_best_only=True,
                    mode="max",
                    verbose=1),

    EarlyStopping(monitor="val_accuracy",
                  patience=5,
                  restore_best_weights=True,
                  mode="max",
                  verbose=1),

    ReduceLROnPlateau(monitor="val_loss",
                      factor=0.3,
                      patience=3,
                      verbose=1)
]

# %%
history_frozen = model_vit.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=10,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8873 - loss: 0.3820
# Epoch 1: val_accuracy improved from 0.88619 to 0.91930, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 450s 190ms/step - accuracy: 0.8898 - loss: 0.3682 - val_accuracy: 0.9193 - val_loss: 0.2682 - learning_rate: 1.0000e-04
# Epoch 2/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9063 - loss: 0.3161
# Epoch 2: val_accuracy improved from 0.91930 to 0.93341, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 448s 189ms/step - accuracy: 0.9080 - loss: 0.3067 - val_accuracy: 0.9334 - val_loss: 0.2265 - learning_rate: 1.0000e-04
# Epoch 3/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9164 - loss: 0.2703
# Epoch 3: val_accuracy improved from 0.93341 to 0.93856, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 449s 189ms/step - accuracy: 0.9170 - loss: 0.2684 - val_accuracy: 0.9386 - val_loss: 0.2063 - learning_rate: 1.0000e-04
# Epoch 4/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9260 - loss: 0.2400
# Epoch 4: val_accuracy improved from 0.93856 to 0.94322, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 449s 189ms/step - accuracy: 0.9245 - loss: 0.2447 - val_accuracy: 0.9432 - val_loss: 0.1851 - learning_rate: 1.0000e-04
# Epoch 5/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9274 - loss: 0.2345
# Epoch 5: val_accuracy improved from 0.94322 to 0.94702, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 448s 189ms/step - accuracy: 0.9298 - loss: 0.2264 - val_accuracy: 0.9470 - val_loss: 0.1704 - learning_rate: 1.0000e-04
# Epoch 6/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9329 - loss: 0.2153
# Epoch 6: val_accuracy improved from 0.94702 to 0.94886, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 450s 190ms/step - accuracy: 0.9347 - loss: 0.2132 - val_accuracy: 0.9489 - val_loss: 0.1620 - learning_rate: 1.0000e-04
# Epoch 7/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9368 - loss: 0.2004
# Epoch 7: val_accuracy improved from 0.94886 to 0.95107, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 447s 188ms/step - accuracy: 0.9359 - loss: 0.2042 - val_accuracy: 0.9511 - val_loss: 0.1538 - learning_rate: 1.0000e-04
# Epoch 8/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9400 - loss: 0.1955
# Epoch 8: val_accuracy improved from 0.95107 to 0.95389, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 457s 193ms/step - accuracy: 0.9408 - loss: 0.1918 - val_accuracy: 0.9539 - val_loss: 0.1470 - learning_rate: 1.0000e-04
# Epoch 9/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9433 - loss: 0.1854
# Epoch 9: val_accuracy improved from 0.95389 to 0.95450, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 447s 188ms/step - accuracy: 0.9432 - loss: 0.1842 - val_accuracy: 0.9545 - val_loss: 0.1420 - learning_rate: 1.0000e-04
# Epoch 10/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9443 - loss: 0.1797
# Epoch 10: val_accuracy improved from 0.95450 to 0.95548, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 448s 189ms/step - accuracy: 0.9429 - loss: 0.1787 - val_accuracy: 0.9555 - val_loss: 0.1396 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 10.

# %%
for layer in base.layers[-4:]:
    layer.trainable = True

model_vit.compile(optimizer=Adam(1e-5),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])

history_ft = model_vit.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=10,
    callbacks=callbacks
)
# Out:
# Epoch 1/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9500 - loss: 0.1525
# Epoch 1: val_accuracy improved from 0.95548 to 0.96640, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 529s 206ms/step - accuracy: 0.9544 - loss: 0.1385 - val_accuracy: 0.9664 - val_loss: 0.0974 - learning_rate: 1.0000e-05
# Epoch 2/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9609 - loss: 0.1158
# Epoch 2: val_accuracy improved from 0.96640 to 0.96860, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 465s 196ms/step - accuracy: 0.9636 - loss: 0.1080 - val_accuracy: 0.9686 - val_loss: 0.0882 - learning_rate: 1.0000e-05
# Epoch 3/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9681 - loss: 0.0928
# Epoch 3: val_accuracy improved from 0.96860 to 0.97388, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 463s 195ms/step - accuracy: 0.9692 - loss: 0.0903 - val_accuracy: 0.9739 - val_loss: 0.0730 - learning_rate: 1.0000e-05
# Epoch 4/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9716 - loss: 0.0850
# Epoch 4: val_accuracy improved from 0.97388 to 0.97486, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 459s 193ms/step - accuracy: 0.9722 - loss: 0.0821 - val_accuracy: 0.9749 - val_loss: 0.0683 - learning_rate: 1.0000e-05
# Epoch 5/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9753 - loss: 0.0741
# Epoch 5: val_accuracy improved from 0.97486 to 0.97523, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 461s 194ms/step - accuracy: 0.9758 - loss: 0.0729 - val_accuracy: 0.9752 - val_loss: 0.0677 - learning_rate: 1.0000e-05
# Epoch 6/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9779 - loss: 0.0663
# Epoch 6: val_accuracy improved from 0.97523 to 0.97964, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 465s 196ms/step - accuracy: 0.9781 - loss: 0.0670 - val_accuracy: 0.9796 - val_loss: 0.0593 - learning_rate: 1.0000e-05
# Epoch 7/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9808 - loss: 0.0576
# Epoch 7: val_accuracy improved from 0.97964 to 0.98173, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 460s 194ms/step - accuracy: 0.9797 - loss: 0.0603 - val_accuracy: 0.9817 - val_loss: 0.0504 - learning_rate: 1.0000e-05
# Epoch 8/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9831 - loss: 0.0536
# Epoch 8: val_accuracy improved from 0.98173 to 0.98344, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 462s 195ms/step - accuracy: 0.9825 - loss: 0.0538 - val_accuracy: 0.9834 - val_loss: 0.0514 - learning_rate: 1.0000e-05
# Epoch 9/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9815 - loss: 0.0530
# Epoch 9: val_accuracy did not improve from 0.98344
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 459s 193ms/step - accuracy: 0.9826 - loss: 0.0518 - val_accuracy: 0.9833 - val_loss: 0.0476 - learning_rate: 1.0000e-05
# Epoch 10/10
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9826 - loss: 0.0502
# Epoch 10: val_accuracy improved from 0.98344 to 0.98467, saving model to /kaggle/working/vit_best.h5
# 2374/2374 ━━━━━━━━━━━━━━━━━━━━ 463s 195ms/step - accuracy: 0.9837 - loss: 0.0483 - val_accuracy: 0.9847 - val_loss: 0.0462 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 10.

# %%
import numpy as np
from sklearn.metrics import classification_report

test_generator.reset()

# Predictions
y_pred = model_vit.predict(test_generator, steps=test_generator.samples // BATCH_SIZE + 1, verbose=1)
y_pred_classes = np.argmax(y_pred, axis=1)

# True labels
y_true = test_generator.classes
class_names = list(train_generator.class_indices.keys())

report = classification_report(y_true, y_pred_classes, target_names=class_names)
print("Classification Report (ViT):\n")
print(report)
# Out:
# 510/510 ━━━━━━━━━━━━━━━━━━━━ 54s 100ms/step
# Classification Report (ViT):
#
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       1.00      0.96      0.98        95
#                                  Apple___Black_rot       0.99      1.00      0.99        94
#                           Apple___Cedar_apple_rust       1.00      1.00      1.00        42
#                                    Apple___healthy       0.99      1.00      0.99       246
#                                Blueberry___healthy       0.99      1.00      1.00       226
#           Cherry_(including_sour)___Powdery_mildew       1.00      0.99      1.00       158
#                  Cherry_(including_sour)___healthy       1.00      0.99      1.00       129
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.84      0.92      0.88        77
#                        Corn_(maize)___Common_rust_       0.99      1.00      1.00       179
#                Corn_(maize)___Northern_Leaf_Blight       0.96      0.90      0.93       148
#                             Corn_(maize)___healthy       1.00      1.00      1.00       175
#                                  Grape___Black_rot       1.00      0.99      0.99       177
#                       Grape___Esca_(Black_Measles)       1.00      1.00      1.00       208
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.99      1.00      1.00       162
#                                    Grape___healthy       1.00      1.00      1.00        64
#           Orange___Haunglongbing_(Citrus_greening)       0.99      1.00      1.00       827
#                             Peach___Bacterial_spot       1.00      1.00      1.00       345
#                                    Peach___healthy       0.98      1.00      0.99        54
#                      Pepper,_bell___Bacterial_spot       0.99      0.97      0.98       150
#                             Pepper,_bell___healthy       0.96      1.00      0.98       222
#                              Potato___Early_blight       1.00      0.99      0.99       150
#                               Potato___Late_blight       0.99      0.97      0.98       150
#                                   Potato___healthy       0.92      0.96      0.94        23
#                                Raspberry___healthy       1.00      1.00      1.00        56
#                                  Soybean___healthy       1.00      0.99      1.00       764
#                            Squash___Powdery_mildew       1.00      1.00      1.00       276
#                           Strawberry___Leaf_scorch       0.99      1.00      1.00       167
#                               Strawberry___healthy       1.00      1.00      1.00        69
#                            Tomato___Bacterial_spot       0.98      0.97      0.98       320
#                              Tomato___Early_blight       0.95      0.87      0.91       150
#                               Tomato___Late_blight       0.96      0.95      0.96       286
#                                 Tomato___Leaf_Mold       0.97      0.97      0.97       143
#                        Tomato___Septoria_leaf_spot       0.96      0.98      0.97       266
#      Tomato___Spider_mites Two-spotted_spider_mite       0.92      1.00      0.95       252
#                               Tomato___Target_Spot       0.95      0.87      0.91       211
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       1.00      1.00      1.00       804
#                       Tomato___Tomato_mosaic_virus       1.00      0.96      0.98        56
#                                   Tomato___healthy       0.97      1.00      0.98       238
#
#                                           accuracy                           0.98      8159
#                                          macro avg       0.98      0.98      0.98      8159
#                                       weighted avg       0.98      0.98      0.98      8159

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', cbar=False) # Changed to Greens for distinction
plt.title('Confusion Matrix - Vision Transformer (ViT)')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
plt.figure(figsize=(14,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history_frozen.history['accuracy'] + history_ft.history['accuracy'], label='Train Accuracy')
plt.plot(history_frozen.history['val_accuracy'] + history_ft.history['val_accuracy'], label='Validation Accuracy')
plt.title('Vision Transformer Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(history_frozen.history['loss'] + history_ft.history['loss'], label='Train Loss')
plt.plot(history_frozen.history['val_loss'] + history_ft.history['val_loss'], label='Validation Loss')
plt.title('Vision Transformer Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

y_true_bin = label_binarize(y_true, classes=np.arange(len(class_names)))
if y_true_bin.ndim == 1:
    y_true_bin = y_true_bin.reshape(-1, 1)

plt.figure(figsize=(12,10))
for i in range(len(class_names)):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{class_names[i]} (AUC = {roc_auc:.3f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random (AUC = 0.5)')
plt.title('ROC Curves - Vision Transformer')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right", fontsize=8, ncol=2)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
final_path = "/kaggle/working/vit_final_state.h5"
model_vit.save(final_path)
print(f"\n✅ ViT Final (Fine-Tuned) model state saved to: {final_path}")
# Out:
# ✅ ViT Final (Fine-Tuned) model state saved to: /kaggle/working/vit_final_state.h5
